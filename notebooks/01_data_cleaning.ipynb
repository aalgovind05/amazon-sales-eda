# %%
import pandas as pd
import numpy as nb
import matplotlib .pyplot as plt
import seaborn as sns

# %%
df_raw = pd.read_csv('../data/Amazon_Sale_Report.csv')
# Out:
# C:\Users\aalgo\AppData\Local\Temp\ipykernel_27664\2804123620.py:1: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv('../data/Amazon_Sale_Report.csv')

# %%
df_raw.shape
# Out:
# (128975, 24)
